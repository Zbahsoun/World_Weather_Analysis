# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iquique
# Processing Record 2 of Set 1 | jacobina
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | oranjemund
# Processing Record 9 of Set 1 | tucurui
# Processing Record 10 of Set 1 | vestmanna
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | dolores
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | mayo
# Processing Record 16 of Set 1 | campagna
# Processing Record 17 of Set 1 | avera
# Processing Record 18 of Set 1 | hami
# Processing Record 19 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 1 | soavinandriana
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | merke
# Processing Record 23 of Set 1 | knysna
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | plouzane
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | dakar
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | kumo
# Processing Record 36 of Set 1 | atar
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | asau
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | berlevag
# Processing Record 44 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | faridan
# City not found. Skipping...
# Processing Record 48 of Set 1 | viedma
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | rawlins
# Processing Record 1 of Set 2 | nouakchott
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | manono
# Processing Record 4 of Set 2 | aviles
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | bekhteyevka
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | sambava
# Processing Record 9 of Set 2 | urumqi
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | kudahuvadhoo
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | los llanos de aridane
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | polunochnoye
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | subang
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | nizhnyaya poyma
# Processing Record 24 of Set 2 | itaituba
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | palmer
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | torit
# Processing Record 31 of Set 2 | xingcheng
# Processing Record 32 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | avanigadda
# Processing Record 35 of Set 2 | rosetown
# Processing Record 36 of Set 2 | severodvinsk
# Processing Record 37 of Set 2 | belmonte
# Processing Record 38 of Set 2 | pringsewu
# Processing Record 39 of Set 2 | vanavara
# Processing Record 40 of Set 2 | abalak
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | mehamn
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | juneau
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | luena
# Processing Record 48 of Set 2 | shingu
# Processing Record 49 of Set 2 | kasane
# Processing Record 50 of Set 2 | yenagoa
# Processing Record 1 of Set 3 | pareora
# Processing Record 2 of Set 3 | ibotirama
# Processing Record 3 of Set 3 | xuanhua
# Processing Record 4 of Set 3 | olafsvik
# Processing Record 5 of Set 3 | birao
# Processing Record 6 of Set 3 | ampanihy
# Processing Record 7 of Set 3 | kainantu
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | kandrian
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | flin flon
# Processing Record 13 of Set 3 | andahuaylas
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | shimanovsk
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | umtata
# Processing Record 19 of Set 3 | vardo
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | alegrete
# Processing Record 23 of Set 3 | salalah
# Processing Record 24 of Set 3 | alihe
# Processing Record 25 of Set 3 | akureyri
# Processing Record 26 of Set 3 | hayden
# Processing Record 27 of Set 3 | skovde
# City not found. Skipping...
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | gimli
# Processing Record 30 of Set 3 | faya
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | jibuti
# Processing Record 33 of Set 3 | anadyr
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | buluang
# Processing Record 37 of Set 3 | quesnel
# Processing Record 38 of Set 3 | khasan
# Processing Record 39 of Set 3 | hakodate
# Processing Record 40 of Set 3 | kushima
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | sao filipe
# Processing Record 45 of Set 3 | hailun
# Processing Record 46 of Set 3 | pemberton
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | radford
# Processing Record 49 of Set 3 | nijar
# Processing Record 50 of Set 3 | krasnovishersk
# Processing Record 1 of Set 4 | lubao
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | khorramabad
# Processing Record 4 of Set 4 | mikhaylov
# Processing Record 5 of Set 4 | faanui
# Processing Record 6 of Set 4 | necochea
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | jamestown
# Processing Record 9 of Set 4 | bichena
# Processing Record 10 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 4 | rawson
# Processing Record 12 of Set 4 | omsukchan
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | makinsk
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | zhigansk
# Processing Record 17 of Set 4 | paragominas
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | tilichiki
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | kupang
# Processing Record 27 of Set 4 | aberdeen
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 4 | auki
# Processing Record 32 of Set 4 | barranca
# Processing Record 33 of Set 4 | dingle
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | morro bay
# Processing Record 36 of Set 4 | sur
# Processing Record 37 of Set 4 | ilebo
# Processing Record 38 of Set 4 | taburao
# City not found. Skipping...
# Processing Record 39 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 4 | suao
# City not found. Skipping...
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | ballina
# Processing Record 44 of Set 4 | chara
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | esil
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | champasak
# Processing Record 1 of Set 5 | todos santos
# Processing Record 2 of Set 5 | manakara
# Processing Record 3 of Set 5 | egvekinot
# Processing Record 4 of Set 5 | tasiilaq
# Processing Record 5 of Set 5 | tombouctou
# Processing Record 6 of Set 5 | tuktoyaktuk
# Processing Record 7 of Set 5 | mao
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | bereda
# Processing Record 11 of Set 5 | port arthur
# Processing Record 12 of Set 5 | exeter
# Processing Record 13 of Set 5 | omboue
# Processing Record 14 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | requena
# Processing Record 17 of Set 5 | camacha
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | stratonion
# Processing Record 20 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 21 of Set 5 | katherine
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | denia
# Processing Record 24 of Set 5 | yumen
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | berbera
# Processing Record 27 of Set 5 | saint-francois
# Processing Record 28 of Set 5 | waingapu
# Processing Record 29 of Set 5 | kutum
# Processing Record 30 of Set 5 | pak thong chai
# Processing Record 31 of Set 5 | sangar
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | baoro
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | palamos
# Processing Record 36 of Set 5 | abashiri
# Processing Record 37 of Set 5 | kyra
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | norman wells
# Processing Record 40 of Set 5 | meulaboh
# Processing Record 41 of Set 5 | kozhva
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | srednekolymsk
# Processing Record 44 of Set 5 | suntar
# Processing Record 45 of Set 5 | cambyreta
# City not found. Skipping...
# Processing Record 46 of Set 5 | dumas
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | christchurch
# Processing Record 49 of Set 5 | natitingou
# Processing Record 50 of Set 5 | cidreira
# Processing Record 1 of Set 6 | acapulco
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | iwanai
# Processing Record 5 of Set 6 | sola
# Processing Record 6 of Set 6 | kargil
# Processing Record 7 of Set 6 | jian
# Processing Record 8 of Set 6 | moranbah
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | shanghai
# Processing Record 11 of Set 6 | eyl
# Processing Record 12 of Set 6 | kapaa
# Processing Record 13 of Set 6 | muyezerskiy
# Processing Record 14 of Set 6 | lashio
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | ostrovnoy
# Processing Record 18 of Set 6 | kyren
# Processing Record 19 of Set 6 | disna
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | bowen
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | bethel
# Processing Record 24 of Set 6 | athabasca
# Processing Record 25 of Set 6 | klyuchi
# Processing Record 26 of Set 6 | kavieng
# Processing Record 27 of Set 6 | sinnamary
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | rundu
# Processing Record 30 of Set 6 | warmbad
# Processing Record 31 of Set 6 | linxia
# Processing Record 32 of Set 6 | naivasha
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | leningradskiy
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | balad
# Processing Record 39 of Set 6 | mineros
# Processing Record 40 of Set 6 | puerto narino
# Processing Record 41 of Set 6 | letlhakane
# Processing Record 42 of Set 6 | katobu
# Processing Record 43 of Set 6 | ishigaki
# Processing Record 44 of Set 6 | new norfolk
# Processing Record 45 of Set 6 | makakilo city
# Processing Record 46 of Set 6 | fairbanks
# Processing Record 47 of Set 6 | jizan
# Processing Record 48 of Set 6 | provideniya
# Processing Record 49 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 6 | mahajanga
# Processing Record 1 of Set 7 | tambacounda
# Processing Record 2 of Set 7 | durusu
# Processing Record 3 of Set 7 | alimanguan
# City not found. Skipping...
# Processing Record 4 of Set 7 | mogadishu
# Processing Record 5 of Set 7 | vila velha
# Processing Record 6 of Set 7 | saint anthony
# Processing Record 7 of Set 7 | beatrice
# Processing Record 8 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 7 | lima
# Processing Record 10 of Set 7 | port-cartier
# Processing Record 11 of Set 7 | korhogo
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | simbahan
# Processing Record 14 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | forestville
# Processing Record 16 of Set 7 | asfi
# Processing Record 17 of Set 7 | karachi
# Processing Record 18 of Set 7 | west wendover
# Processing Record 19 of Set 7 | konosha
# Processing Record 20 of Set 7 | henties bay
# Processing Record 21 of Set 7 | general roca
# Processing Record 22 of Set 7 | nea peramos
# Processing Record 23 of Set 7 | corinth
# Processing Record 24 of Set 7 | olga
# Processing Record 25 of Set 7 | tecoanapa
# Processing Record 26 of Set 7 | huron
# Processing Record 27 of Set 7 | sao felix do xingu
# Processing Record 28 of Set 7 | ibbenburen
# Processing Record 29 of Set 7 | glazov
# Processing Record 30 of Set 7 | monrovia
# Processing Record 31 of Set 7 | kichera
# Processing Record 32 of Set 7 | terney
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | harper
# Processing Record 39 of Set 7 | gizo
# Processing Record 40 of Set 7 | nioro
# Processing Record 41 of Set 7 | dali
# Processing Record 42 of Set 7 | havelock
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | meadow lake
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | crotone
# Processing Record 47 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | pishin
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | chinsali
# Processing Record 4 of Set 8 | okitipupa
# Processing Record 5 of Set 8 | southbridge
# Processing Record 6 of Set 8 | gillette
# Processing Record 7 of Set 8 | shelburne
# Processing Record 8 of Set 8 | pemangkat
# Processing Record 9 of Set 8 | cobija
# Processing Record 10 of Set 8 | balkhash
# Processing Record 11 of Set 8 | novobiryusinskiy
# Processing Record 12 of Set 8 | poronaysk
# Processing Record 13 of Set 8 | barra patuca
# Processing Record 14 of Set 8 | alta floresta
# Processing Record 15 of Set 8 | mahebourg
# Processing Record 16 of Set 8 | kaeo
# Processing Record 17 of Set 8 | chifeng
# Processing Record 18 of Set 8 | pattaya
# Processing Record 19 of Set 8 | sarkand
# Processing Record 20 of Set 8 | dwarka
# Processing Record 21 of Set 8 | fare
# Processing Record 22 of Set 8 | yerbogachen
# Processing Record 23 of Set 8 | saryagash
# Processing Record 24 of Set 8 | bilma
# Processing Record 25 of Set 8 | bardiyah
# Processing Record 26 of Set 8 | tezu
# Processing Record 27 of Set 8 | shaoyang
# Processing Record 28 of Set 8 | key west
# Processing Record 29 of Set 8 | renigunta
# Processing Record 30 of Set 8 | azare
# Processing Record 31 of Set 8 | orlik
# Processing Record 32 of Set 8 | bontang
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | korla
# Processing Record 36 of Set 8 | adeje
# Processing Record 37 of Set 8 | komatsu
# Processing Record 38 of Set 8 | manggar
# Processing Record 39 of Set 8 | fort nelson
# Processing Record 40 of Set 8 | aksha
# Processing Record 41 of Set 8 | balabac
# Processing Record 42 of Set 8 | griffith
# Processing Record 43 of Set 8 | quatre cocos
# Processing Record 44 of Set 8 | sokol
# Processing Record 45 of Set 8 | ambilobe
# Processing Record 46 of Set 8 | ponnani
# Processing Record 47 of Set 8 | walvis bay
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | borogontsy
# Processing Record 50 of Set 8 | comodoro rivadavia
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | duz
# City not found. Skipping...
# Processing Record 3 of Set 9 | cooma
# Processing Record 4 of Set 9 | houston
# Processing Record 5 of Set 9 | mankono
# Processing Record 6 of Set 9 | klaksvik
# Processing Record 7 of Set 9 | nizhniy kuranakh
# Processing Record 8 of Set 9 | kailua
# Processing Record 9 of Set 9 | bashtanka
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 9 | bumbuna
# Processing Record 13 of Set 9 | yar-sale
# Processing Record 14 of Set 9 | pemba
# Processing Record 15 of Set 9 | turukhansk
# Processing Record 16 of Set 9 | mantua
# Processing Record 17 of Set 9 | huarmey
# Processing Record 18 of Set 9 | ketchikan
# Processing Record 19 of Set 9 | wattegama
# Processing Record 20 of Set 9 | hamilton
# Processing Record 21 of Set 9 | tabligbo
# Processing Record 22 of Set 9 | sharlyk
# Processing Record 23 of Set 9 | derzhavinsk
# Processing Record 24 of Set 9 | tiznit
# Processing Record 25 of Set 9 | felipe carrillo puerto
# Processing Record 26 of Set 9 | morros
# Processing Record 27 of Set 9 | krasnaya gora
# Processing Record 28 of Set 9 | bintulu
# Processing Record 29 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 30 of Set 9 | mhango
# Processing Record 31 of Set 9 | baker city
# Processing Record 32 of Set 9 | ayan
# Processing Record 33 of Set 9 | grindavik
# Processing Record 34 of Set 9 | baijiantan
# Processing Record 35 of Set 9 | red bank
# Processing Record 36 of Set 9 | yetholm
# City not found. Skipping...
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | sakete
# Processing Record 39 of Set 9 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 40 of Set 9 | zurrieq
# Processing Record 41 of Set 9 | santa cruz
# Processing Record 42 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 9 | yelizovo
# Processing Record 44 of Set 9 | vestmannaeyjar
# Processing Record 45 of Set 9 | zabaykalsk
# Processing Record 46 of Set 9 | lupiro
# Processing Record 47 of Set 9 | doha
# Processing Record 48 of Set 9 | ukrayinka
# Processing Record 49 of Set 9 | new milford
# Processing Record 50 of Set 9 | mandalgovi
# Processing Record 1 of Set 10 | reconquista
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | bathsheba
# Processing Record 4 of Set 10 | tenenkou
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | oistins
# Processing Record 7 of Set 10 | keelung
# Processing Record 8 of Set 10 | zhanaozen
# Processing Record 9 of Set 10 | chazuta
# Processing Record 10 of Set 10 | beirut
# Processing Record 11 of Set 10 | lasa
# Processing Record 12 of Set 10 | saint-georges
# Processing Record 13 of Set 10 | roma
# Processing Record 14 of Set 10 | okhotsk
# Processing Record 15 of Set 10 | togur
# Processing Record 16 of Set 10 | gulariya
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 10 | lamont
# Processing Record 20 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 10 | naze
# Processing Record 23 of Set 10 | epe
# Processing Record 24 of Set 10 | cheremshan
# Processing Record 25 of Set 10 | terrace bay
# Processing Record 26 of Set 10 | aguimes
# Processing Record 27 of Set 10 | siilinjarvi
# Processing Record 28 of Set 10 | vaitape
# Processing Record 29 of Set 10 | gambo
# Processing Record 30 of Set 10 | bolitoc
# Processing Record 31 of Set 10 | ilheus
# Processing Record 32 of Set 10 | samarai
# Processing Record 33 of Set 10 | hinton
# Processing Record 34 of Set 10 | taoudenni
# Processing Record 35 of Set 10 | witney
# Processing Record 36 of Set 10 | san vicente
# Processing Record 37 of Set 10 | lyubar
# Processing Record 38 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 39 of Set 10 | zhenjiang
# Processing Record 40 of Set 10 | huainan
# Processing Record 41 of Set 10 | baturaja
# Processing Record 42 of Set 10 | boone
# Processing Record 43 of Set 10 | hofn
# Processing Record 44 of Set 10 | caxias
# Processing Record 45 of Set 10 | axim
# Processing Record 46 of Set 10 | lompoc
# Processing Record 47 of Set 10 | cholet
# Processing Record 48 of Set 10 | houma
# Processing Record 49 of Set 10 | rio grande
# Processing Record 50 of Set 10 | lata
# Processing Record 1 of Set 11 | caraballeda
# Processing Record 2 of Set 11 | burnie
# Processing Record 3 of Set 11 | midland
# Processing Record 4 of Set 11 | plettenberg bay
# Processing Record 5 of Set 11 | codrington
# Processing Record 6 of Set 11 | myrtle beach
# Processing Record 7 of Set 11 | gasa
# Processing Record 8 of Set 11 | kangaatsiaq
# Processing Record 9 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 10 of Set 11 | novikovo
# Processing Record 11 of Set 11 | eureka
# Processing Record 12 of Set 11 | filingue
# Processing Record 13 of Set 11 | zlobin
# Processing Record 14 of Set 11 | priladozhskiy
# Processing Record 15 of Set 11 | talcahuano
# Processing Record 16 of Set 11 | kilindoni
# Processing Record 17 of Set 11 | whyalla
# Processing Record 18 of Set 11 | kalanguy
# Processing Record 19 of Set 11 | edson
# Processing Record 20 of Set 11 | kungalv
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | pedernales
# Processing Record 23 of Set 11 | khangah dogran
# Processing Record 24 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 11 | nautla
# Processing Record 26 of Set 11 | neiafu
# Processing Record 27 of Set 11 | angoram
# Processing Record 28 of Set 11 | namatanai
# Processing Record 29 of Set 11 | romny
# Processing Record 30 of Set 11 | sarangani
# Processing Record 31 of Set 11 | kobe
# Processing Record 32 of Set 11 | el real de santa maria
# Processing Record 33 of Set 11 | atherton
# Processing Record 34 of Set 11 | chumikan
# Processing Record 35 of Set 11 | port blair
# Processing Record 36 of Set 11 | labrea
# Processing Record 37 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 11 | cayenne
# Processing Record 39 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 11 | tucuman
# Processing Record 42 of Set 11 | cristobal obregon
# Processing Record 43 of Set 11 | naples
# Processing Record 44 of Set 11 | qandala
# Processing Record 45 of Set 11 | vostok
# Processing Record 46 of Set 11 | awbari
# Processing Record 47 of Set 11 | takoradi
# Processing Record 48 of Set 11 | belaya gora
# Processing Record 49 of Set 11 | margate
# Processing Record 50 of Set 11 | goure
# Processing Record 1 of Set 12 | nhulunbuy
# Processing Record 2 of Set 12 | micheweni
# Processing Record 3 of Set 12 | ambanja
# Processing Record 4 of Set 12 | campoverde
# Processing Record 5 of Set 12 | gazli
# Processing Record 6 of Set 12 | flinders
# Processing Record 7 of Set 12 | marzuq
# Processing Record 8 of Set 12 | borba
# Processing Record 9 of Set 12 | antofagasta
# Processing Record 10 of Set 12 | veracruz
# Processing Record 11 of Set 12 | santander
# Processing Record 12 of Set 12 | imbituba
# Processing Record 13 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 12 | kavaratti
# Processing Record 16 of Set 12 | olinda
# Processing Record 17 of Set 12 | cabedelo
# Processing Record 18 of Set 12 | ixtapa
# Processing Record 19 of Set 12 | khuzdar
# Processing Record 20 of Set 12 | kodiak
# Processing Record 21 of Set 12 | saint-joseph
# Processing Record 22 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 12 | mount isa
# Processing Record 25 of Set 12 | lagoa
# Processing Record 26 of Set 12 | pacific grove
# Processing Record 27 of Set 12 | miles city
# Processing Record 28 of Set 12 | alice springs
# Processing Record 29 of Set 12 | kokopo
# Processing Record 30 of Set 12 | lapua
# Processing Record 31 of Set 12 | baruun-urt
# Processing Record 32 of Set 12 | matata
# Processing Record 33 of Set 12 | reading
# Processing Record 34 of Set 12 | north platte
# Processing Record 35 of Set 12 | karuzi
# Processing Record 36 of Set 12 | ugoofaaru
# Processing Record 37 of Set 12 | ashland
# Processing Record 38 of Set 12 | kununurra
# Processing Record 39 of Set 12 | shakiso
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 12 | wuwei
# Processing Record 43 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 12 | oriximina
# Processing Record 45 of Set 12 | gilgit
# Processing Record 46 of Set 12 | jingdezhen
# Processing Record 47 of Set 12 | giyani
# Processing Record 48 of Set 12 | moose factory
# Processing Record 49 of Set 12 | alirajpur
# Processing Record 50 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 13 | jumla
# Processing Record 2 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 13 | palm coast
# Processing Record 4 of Set 13 | grand gaube
# Processing Record 5 of Set 13 | talnakh
# Processing Record 6 of Set 13 | saint-gilles
# Processing Record 7 of Set 13 | tabalosos
# Processing Record 8 of Set 13 | luanda
# Processing Record 9 of Set 13 | ornskoldsvik
# Processing Record 10 of Set 13 | maragogi
# Processing Record 11 of Set 13 | matara
# Processing Record 12 of Set 13 | redlands
# Processing Record 13 of Set 13 | jalu
# Processing Record 14 of Set 13 | touros
# Processing Record 15 of Set 13 | cameta
# Processing Record 16 of Set 13 | alveringem
# Processing Record 17 of Set 13 | horta
# Processing Record 18 of Set 13 | shumskiy
# Processing Record 19 of Set 13 | poya
# Processing Record 20 of Set 13 | batagay-alyta
# Processing Record 21 of Set 13 | nyuksenitsa
# Processing Record 22 of Set 13 | bubaque
# Processing Record 23 of Set 13 | mackay
# Processing Record 24 of Set 13 | hovd
# Processing Record 25 of Set 13 | sistranda
# Processing Record 26 of Set 13 | calvinia
# Processing Record 27 of Set 13 | patitirion
# Processing Record 28 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 13 | roebourne
# Processing Record 30 of Set 13 | uglich
# Processing Record 31 of Set 13 | san carlos
# Processing Record 32 of Set 13 | la palma
# Processing Record 33 of Set 13 | siocon
# Processing Record 34 of Set 13 | troitsko-pechorsk
# Processing Record 35 of Set 13 | zaoyang
# Processing Record 36 of Set 13 | marawi
# Processing Record 37 of Set 13 | pangai
# Processing Record 38 of Set 13 | oktyabrskiy
# Processing Record 39 of Set 13 | beya
# Processing Record 40 of Set 13 | vega de alatorre
# Processing Record 41 of Set 13 | north bend
# Processing Record 42 of Set 13 | jabinyanah
# Processing Record 43 of Set 13 | kahului
# Processing Record 44 of Set 13 | talara
# Processing Record 45 of Set 13 | abu zabad
# Processing Record 46 of Set 13 | oussouye
# Processing Record 47 of Set 13 | zharkent
# Processing Record 48 of Set 13 | winnemucca
# Processing Record 49 of Set 13 | kirakira
# Processing Record 50 of Set 13 | georgiyevskoye
# Processing Record 1 of Set 14 | paamiut
# Processing Record 2 of Set 14 | victor harbor
# Processing Record 3 of Set 14 | xining
# Processing Record 4 of Set 14 | fukue
# Processing Record 5 of Set 14 | moron
# Processing Record 6 of Set 14 | illkirch-graffenstaden
# Processing Record 7 of Set 14 | road town
# Processing Record 8 of Set 14 | port hedland
# Processing Record 9 of Set 14 | aginskoye
# Processing Record 10 of Set 14 | buala
# Processing Record 11 of Set 14 | champerico
# Processing Record 12 of Set 14 | skjervoy
# Processing Record 13 of Set 14 | maibong
# Processing Record 14 of Set 14 | dudinka
# Processing Record 15 of Set 14 | lemon tree passage
# Processing Record 16 of Set 14 | mega
# Processing Record 17 of Set 14 | camana
# Processing Record 18 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 19 of Set 14 | ca mau
# Processing Record 20 of Set 14 | vao
# Processing Record 21 of Set 14 | chaadayevka
# Processing Record 22 of Set 14 | sept-iles
# Processing Record 23 of Set 14 | apac
# Processing Record 24 of Set 14 | pincher creek
# Processing Record 25 of Set 14 | toul
# Processing Record 26 of Set 14 | san angelo
# Processing Record 27 of Set 14 | cockburn town
# Processing Record 28 of Set 14 | alappuzha
# Processing Record 29 of Set 14 | novobessergenevka
# Processing Record 30 of Set 14 | sandur
# Processing Record 31 of Set 14 | solnechnyy
# Processing Record 32 of Set 14 | casablanca
# Processing Record 33 of Set 14 | suhbaatar
# Processing Record 34 of Set 14 | la ciotat
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | horsham
# Processing Record 37 of Set 14 | birsk
# Processing Record 38 of Set 14 | lagos
# Processing Record 39 of Set 14 | sfantu gheorghe
# Processing Record 40 of Set 14 | abu kamal
# Processing Record 41 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 14 | michigan city
# Processing Record 43 of Set 14 | bambanglipuro
# Processing Record 44 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 14 | manati
# Processing Record 46 of Set 14 | merauke
# Processing Record 47 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 14 | dongobesh
# Processing Record 50 of Set 14 | subaytilah
# City not found. Skipping...

# %%
# Print the length of the city_data list then add to a DF
city_data_df = pd.DataFrame(city_data)
city_data_df

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_weather_file = "Weatherpy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
