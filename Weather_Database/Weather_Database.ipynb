# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 778

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao felix do xingu
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | sharjah
# Processing Record 6 of Set 1 | vostok
# Processing Record 7 of Set 1 | sungairaya
# Processing Record 8 of Set 1 | hofn
# Processing Record 9 of Set 1 | sargatskoye
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | havre-saint-pierre
# Processing Record 13 of Set 1 | shimoda
# Processing Record 14 of Set 1 | swan river
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | bambanglipuro
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | myitkyina
# Processing Record 20 of Set 1 | finschhafen
# Processing Record 21 of Set 1 | atherton
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | stepnyak
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | siverek
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | morgan city
# Processing Record 28 of Set 1 | channel-port aux basques
# Processing Record 29 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 30 of Set 1 | anadyr
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | maniitsoq
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | zhongshan
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | mangaldai
# Processing Record 37 of Set 1 | kamaishi
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | odweyne
# Processing Record 41 of Set 1 | ayagoz
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | ullapool
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | ahipara
# Processing Record 47 of Set 1 | mangrol
# Processing Record 48 of Set 1 | altay
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | chernyshevskiy
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | broken hill
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | kismayo
# Processing Record 12 of Set 2 | karak
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | cairns
# Processing Record 15 of Set 2 | marang
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | carman
# Processing Record 18 of Set 2 | kalmunai
# Processing Record 19 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | seymchan
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | denpasar
# Processing Record 31 of Set 2 | tiarei
# Processing Record 32 of Set 2 | codrington
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 2 | eydhafushi
# Processing Record 36 of Set 2 | bogoslovka
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | olafsvik
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | westport
# Processing Record 41 of Set 2 | san vicente
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | lewiston
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | baykit
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | jawhar
# Processing Record 49 of Set 2 | benguela
# Processing Record 50 of Set 2 | ewa beach
# Processing Record 1 of Set 3 | egvekinot
# Processing Record 2 of Set 3 | matara
# Processing Record 3 of Set 3 | pinawa
# Processing Record 4 of Set 3 | sinnamary
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | vanimo
# Processing Record 11 of Set 3 | tracy
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 3 | butembo
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | mokrousovo
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | majene
# Processing Record 24 of Set 3 | northam
# Processing Record 25 of Set 3 | ramanagaram
# Processing Record 26 of Set 3 | eston
# Processing Record 27 of Set 3 | ormara
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | bull savanna
# Processing Record 31 of Set 3 | maldonado
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | lakes entrance
# Processing Record 34 of Set 3 | nome
# Processing Record 35 of Set 3 | tias
# Processing Record 36 of Set 3 | mabai
# Processing Record 37 of Set 3 | bayan
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | latung
# Processing Record 42 of Set 3 | ola
# Processing Record 43 of Set 3 | esso
# Processing Record 44 of Set 3 | turayf
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | srednekolymsk
# Processing Record 47 of Set 3 | colesberg
# Processing Record 48 of Set 3 | albany
# Processing Record 49 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 3 | krasnokamensk
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | suoyarvi
# Processing Record 3 of Set 4 | kununurra
# Processing Record 4 of Set 4 | charcas
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | martapura
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | khani
# Processing Record 9 of Set 4 | asau
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 4 | muros
# Processing Record 13 of Set 4 | sisimiut
# Processing Record 14 of Set 4 | tautira
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | samarai
# Processing Record 18 of Set 4 | ilulissat
# Processing Record 19 of Set 4 | honiara
# Processing Record 20 of Set 4 | libertador general san martin
# Processing Record 21 of Set 4 | jamestown
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | beira
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | mao
# Processing Record 26 of Set 4 | tandil
# Processing Record 27 of Set 4 | soligalich
# Processing Record 28 of Set 4 | champerico
# Processing Record 29 of Set 4 | kieta
# Processing Record 30 of Set 4 | husavik
# Processing Record 31 of Set 4 | dhola
# Processing Record 32 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 4 | barrow
# Processing Record 34 of Set 4 | allanmyo
# City not found. Skipping...
# Processing Record 35 of Set 4 | reconquista
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | teguldet
# Processing Record 38 of Set 4 | srandakan
# Processing Record 39 of Set 4 | jeremie
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | villazon
# Processing Record 43 of Set 4 | beckley
# Processing Record 44 of Set 4 | challapata
# Processing Record 45 of Set 4 | hilo
# Processing Record 46 of Set 4 | moroni
# Processing Record 47 of Set 4 | natchitoches
# Processing Record 48 of Set 4 | cabedelo
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | atar
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | lagunas
# Processing Record 3 of Set 5 | itoman
# Processing Record 4 of Set 5 | gambiran
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | thunder bay
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | xiongzhou
# Processing Record 9 of Set 5 | abu samrah
# Processing Record 10 of Set 5 | oistins
# Processing Record 11 of Set 5 | ugoofaaru
# Processing Record 12 of Set 5 | portland
# Processing Record 13 of Set 5 | whitehorse
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | narasimharajapura
# Processing Record 16 of Set 5 | mitsamiouli
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | sao jose da coroa grande
# Processing Record 19 of Set 5 | praia da vitoria
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | sembabule
# Processing Record 22 of Set 5 | paragominas
# Processing Record 23 of Set 5 | sawang daen din
# Processing Record 24 of Set 5 | metehara
# City not found. Skipping...
# Processing Record 25 of Set 5 | longjiang
# Processing Record 26 of Set 5 | rodrigues alves
# Processing Record 27 of Set 5 | sitka
# Processing Record 28 of Set 5 | sawakin
# Processing Record 29 of Set 5 | santa maria
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | dir
# Processing Record 33 of Set 5 | marovoay
# Processing Record 34 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 5 | brae
# Processing Record 36 of Set 5 | celestun
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | hamilton
# Processing Record 39 of Set 5 | muroto
# Processing Record 40 of Set 5 | port hedland
# Processing Record 41 of Set 5 | port hardy
# Processing Record 42 of Set 5 | lazaro cardenas
# Processing Record 43 of Set 5 | kawalu
# Processing Record 44 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 5 | ust-koksa
# Processing Record 46 of Set 5 | sola
# Processing Record 47 of Set 5 | san quintin
# Processing Record 48 of Set 5 | santa isabel do rio negro
# Processing Record 49 of Set 5 | ayan
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | okhotsk
# Processing Record 2 of Set 6 | astoria
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | mabay
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | chicama
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | port dover
# Processing Record 9 of Set 6 | chiang khong
# Processing Record 10 of Set 6 | synya
# Processing Record 11 of Set 6 | lowestoft
# Processing Record 12 of Set 6 | aras
# Processing Record 13 of Set 6 | saint-philippe
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | sibu
# Processing Record 16 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | gobabis
# Processing Record 18 of Set 6 | sao domingos do maranhao
# Processing Record 19 of Set 6 | pemangkat
# Processing Record 20 of Set 6 | villa guerrero
# Processing Record 21 of Set 6 | porto walter
# Processing Record 22 of Set 6 | santa isabel
# Processing Record 23 of Set 6 | jalu
# Processing Record 24 of Set 6 | muzhi
# Processing Record 25 of Set 6 | parana
# Processing Record 26 of Set 6 | kindu
# Processing Record 27 of Set 6 | cabinda
# Processing Record 28 of Set 6 | marzuq
# Processing Record 29 of Set 6 | zheleznodorozhnyy
# Processing Record 30 of Set 6 | kenai
# Processing Record 31 of Set 6 | kirakira
# Processing Record 32 of Set 6 | alugan
# Processing Record 33 of Set 6 | banda aceh
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | varhaug
# Processing Record 36 of Set 6 | huilong
# Processing Record 37 of Set 6 | gamba
# Processing Record 38 of Set 6 | santa vitoria do palmar
# Processing Record 39 of Set 6 | tbilisskaya
# Processing Record 40 of Set 6 | mecca
# Processing Record 41 of Set 6 | moose factory
# Processing Record 42 of Set 6 | whitecourt
# Processing Record 43 of Set 6 | mbandaka
# Processing Record 44 of Set 6 | ban nahin
# Processing Record 45 of Set 6 | loikaw
# Processing Record 46 of Set 6 | sambava
# Processing Record 47 of Set 6 | ust-omchug
# Processing Record 48 of Set 6 | katangli
# Processing Record 49 of Set 6 | singaparna
# Processing Record 50 of Set 6 | flinders
# Processing Record 1 of Set 7 | hualmay
# Processing Record 2 of Set 7 | umm kaddadah
# Processing Record 3 of Set 7 | namibe
# Processing Record 4 of Set 7 | songjianghe
# Processing Record 5 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 7 | nanortalik
# Processing Record 7 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 7 | karla
# Processing Record 9 of Set 7 | chokurdakh
# Processing Record 10 of Set 7 | tuktoyaktuk
# Processing Record 11 of Set 7 | nsukka
# Processing Record 12 of Set 7 | narasannapeta
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | upernavik
# Processing Record 16 of Set 7 | bintulu
# Processing Record 17 of Set 7 | labuan
# Processing Record 18 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 7 | rio gallegos
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | edd
# Processing Record 22 of Set 7 | eyl
# Processing Record 23 of Set 7 | belmonte
# Processing Record 24 of Set 7 | siklos
# Processing Record 25 of Set 7 | oxbow
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | estelle
# Processing Record 29 of Set 7 | dasoguz
# Processing Record 30 of Set 7 | khomeynishahr
# City not found. Skipping...
# Processing Record 31 of Set 7 | san ignacio
# Processing Record 32 of Set 7 | hokitika
# Processing Record 33 of Set 7 | halifax
# Processing Record 34 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 7 | katsuura
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | mozarlandia
# Processing Record 38 of Set 7 | russell
# Processing Record 39 of Set 7 | dingle
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | hanna
# Processing Record 43 of Set 7 | lumphat
# Processing Record 44 of Set 7 | canar
# Processing Record 45 of Set 7 | bonfim
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | garden city
# Processing Record 48 of Set 7 | itupiranga
# Processing Record 49 of Set 7 | whitianga
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | port augusta
# Processing Record 2 of Set 8 | yaransk
# Processing Record 3 of Set 8 | dmitrov
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | luderitz
# Processing Record 6 of Set 8 | karachi
# Processing Record 7 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 8 of Set 8 | taltal
# Processing Record 9 of Set 8 | lopukhiv
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | isangel
# Processing Record 14 of Set 8 | kollo
# Processing Record 15 of Set 8 | fuxin
# Processing Record 16 of Set 8 | victor harbor
# Processing Record 17 of Set 8 | soe
# Processing Record 18 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 8 | sangar
# Processing Record 20 of Set 8 | belaya gora
# Processing Record 21 of Set 8 | makakilo city
# Processing Record 22 of Set 8 | palana
# Processing Record 23 of Set 8 | abu dhabi
# Processing Record 24 of Set 8 | prince rupert
# Processing Record 25 of Set 8 | elliot
# Processing Record 26 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 8 | asuncion mita
# Processing Record 31 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 8 | hanko
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | saltpond
# Processing Record 35 of Set 8 | fougamou
# Processing Record 36 of Set 8 | chuncheng
# Processing Record 37 of Set 8 | half moon bay
# Processing Record 38 of Set 8 | nizwa
# Processing Record 39 of Set 8 | iranshahr
# Processing Record 40 of Set 8 | naze
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | kargil
# Processing Record 43 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | sale
# Processing Record 46 of Set 8 | coahuayana
# Processing Record 47 of Set 8 | bom jesus
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | juneau
# Processing Record 50 of Set 8 | myaundzha
# Processing Record 1 of Set 9 | saurimo
# Processing Record 2 of Set 9 | gorontalo
# Processing Record 3 of Set 9 | mombaca
# Processing Record 4 of Set 9 | emerald
# Processing Record 5 of Set 9 | avera
# Processing Record 6 of Set 9 | novyy urgal
# Processing Record 7 of Set 9 | mount isa
# Processing Record 8 of Set 9 | keningau
# Processing Record 9 of Set 9 | kot diji
# Processing Record 10 of Set 9 | vitim
# Processing Record 11 of Set 9 | touros
# Processing Record 12 of Set 9 | isla mujeres
# Processing Record 13 of Set 9 | cap malheureux
# Processing Record 14 of Set 9 | shache
# Processing Record 15 of Set 9 | pisco
# Processing Record 16 of Set 9 | souillac
# Processing Record 17 of Set 9 | barretos
# Processing Record 18 of Set 9 | komsomolskiy
# Processing Record 19 of Set 9 | makinsk
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | kiunga
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | athabasca
# Processing Record 24 of Set 9 | port moresby
# Processing Record 25 of Set 9 | cayenne
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | menomonie
# Processing Record 28 of Set 9 | aykhal
# Processing Record 29 of Set 9 | omsukchan
# Processing Record 30 of Set 9 | bonavista
# Processing Record 31 of Set 9 | youghal
# Processing Record 32 of Set 9 | grand gaube
# Processing Record 33 of Set 9 | praya
# Processing Record 34 of Set 9 | kuli
# Processing Record 35 of Set 9 | kavarna
# Processing Record 36 of Set 9 | norwich
# Processing Record 37 of Set 9 | san jose
# Processing Record 38 of Set 9 | zhezkazgan
# Processing Record 39 of Set 9 | adre
# Processing Record 40 of Set 9 | mchinji
# Processing Record 41 of Set 9 | aitape
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | bolshoy log
# City not found. Skipping...
# Processing Record 44 of Set 9 | chabahar
# Processing Record 45 of Set 9 | savalou
# Processing Record 46 of Set 9 | safaga
# Processing Record 47 of Set 9 | walvis bay
# Processing Record 48 of Set 9 | pacific grove
# Processing Record 49 of Set 9 | lhokseumawe
# Processing Record 50 of Set 9 | lake charles
# Processing Record 1 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 10 | gua musang
# Processing Record 3 of Set 10 | acapulco
# Processing Record 4 of Set 10 | shahreza
# Processing Record 5 of Set 10 | rudabanya
# Processing Record 6 of Set 10 | pitimbu
# Processing Record 7 of Set 10 | fairbanks
# Processing Record 8 of Set 10 | tukrah
# Processing Record 9 of Set 10 | elat
# Processing Record 10 of Set 10 | abengourou
# Processing Record 11 of Set 10 | winnemucca
# Processing Record 12 of Set 10 | tiksi
# Processing Record 13 of Set 10 | nishihara
# Processing Record 14 of Set 10 | hailar
# Processing Record 15 of Set 10 | bibiani
# Processing Record 16 of Set 10 | eureka
# Processing Record 17 of Set 10 | fare
# Processing Record 18 of Set 10 | flin flon
# Processing Record 19 of Set 10 | dinguiraye
# Processing Record 20 of Set 10 | karasburg
# Processing Record 21 of Set 10 | pervomayskiy
# Processing Record 22 of Set 10 | vereshchagino
# Processing Record 23 of Set 10 | mosquera
# Processing Record 24 of Set 10 | itarema
# Processing Record 25 of Set 10 | gouyave
# Processing Record 26 of Set 10 | aberdeen
# Processing Record 27 of Set 10 | rio tercero
# Processing Record 28 of Set 10 | umm lajj
# Processing Record 29 of Set 10 | rockhampton
# Processing Record 30 of Set 10 | kalga
# Processing Record 31 of Set 10 | maturin
# Processing Record 32 of Set 10 | aksay
# Processing Record 33 of Set 10 | haines junction
# Processing Record 34 of Set 10 | santiago
# Processing Record 35 of Set 10 | morros
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | machinga
# Processing Record 38 of Set 10 | arlit
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | jiaocheng
# Processing Record 41 of Set 10 | morada nova
# Processing Record 42 of Set 10 | cabanas
# Processing Record 43 of Set 10 | vestmanna
# Processing Record 44 of Set 10 | wad madani
# Processing Record 45 of Set 10 | alta gracia
# Processing Record 46 of Set 10 | kraskino
# Processing Record 47 of Set 10 | pucallpa
# Processing Record 48 of Set 10 | minsk
# Processing Record 49 of Set 10 | karratha
# Processing Record 50 of Set 10 | mme
# City not found. Skipping...
# Processing Record 1 of Set 11 | palmer
# Processing Record 2 of Set 11 | skjervoy
# Processing Record 3 of Set 11 | kalakamati
# Processing Record 4 of Set 11 | moree
# Processing Record 5 of Set 11 | qasigiannguit
# Processing Record 6 of Set 11 | laje
# Processing Record 7 of Set 11 | suntar
# Processing Record 8 of Set 11 | meiktila
# Processing Record 9 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 11 | langsa
# Processing Record 11 of Set 11 | saint george
# Processing Record 12 of Set 11 | nohar
# Processing Record 13 of Set 11 | hailey
# Processing Record 14 of Set 11 | san cristobal
# Processing Record 15 of Set 11 | dusti
# Processing Record 16 of Set 11 | kabo
# Processing Record 17 of Set 11 | bubaque
# Processing Record 18 of Set 11 | ardakan
# Processing Record 19 of Set 11 | diffa
# Processing Record 20 of Set 11 | mombetsu
# Processing Record 21 of Set 11 | juba
# Processing Record 22 of Set 11 | aleksandrovsk
# Processing Record 23 of Set 11 | aloleng
# Processing Record 24 of Set 11 | mandurah
# Processing Record 25 of Set 11 | dhidhdhoo
# Processing Record 26 of Set 11 | allapalli
# Processing Record 27 of Set 11 | jurm
# Processing Record 28 of Set 11 | cave spring
# Processing Record 29 of Set 11 | neuquen
# Processing Record 30 of Set 11 | minna
# Processing Record 31 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | tosham
# Processing Record 33 of Set 11 | boksitogorsk
# Processing Record 34 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 35 of Set 11 | chapais
# Processing Record 36 of Set 11 | pangnirtung
# Processing Record 37 of Set 11 | buala
# Processing Record 38 of Set 11 | indiana
# Processing Record 39 of Set 11 | cururupu
# Processing Record 40 of Set 11 | talcahuano
# Processing Record 41 of Set 11 | karema
# Processing Record 42 of Set 11 | cockburn town
# Processing Record 43 of Set 11 | bud
# Processing Record 44 of Set 11 | jiaonan
# Processing Record 45 of Set 11 | kashi
# Processing Record 46 of Set 11 | pietarsaari
# Processing Record 47 of Set 11 | ciudad bolivar
# Processing Record 48 of Set 11 | ovsyanka
# Processing Record 49 of Set 11 | solnechnogorsk
# Processing Record 50 of Set 11 | birjand
# Processing Record 1 of Set 12 | puerto baquerizo moreno
# Processing Record 2 of Set 12 | gonzalez
# Processing Record 3 of Set 12 | balikpapan
# Processing Record 4 of Set 12 | santa cruz de tenerife
# Processing Record 5 of Set 12 | bosaso
# Processing Record 6 of Set 12 | beringovskiy
# Processing Record 7 of Set 12 | shubarkuduk
# Processing Record 8 of Set 12 | kailua
# Processing Record 9 of Set 12 | cabra
# Processing Record 10 of Set 12 | dudinka
# Processing Record 11 of Set 12 | sur
# Processing Record 12 of Set 12 | saint anthony
# Processing Record 13 of Set 12 | roebourne
# Processing Record 14 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 12 | newton
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | marsh harbour
# Processing Record 18 of Set 12 | maxixe
# Processing Record 19 of Set 12 | englewood
# Processing Record 20 of Set 12 | leh
# Processing Record 21 of Set 12 | novochernorechenskiy
# Processing Record 22 of Set 12 | saint-pierre
# Processing Record 23 of Set 12 | nizhneangarsk
# Processing Record 24 of Set 12 | shetpe
# Processing Record 25 of Set 12 | ziarat
# Processing Record 26 of Set 12 | kijang
# Processing Record 27 of Set 12 | polur
# Processing Record 28 of Set 12 | sidi ali
# Processing Record 29 of Set 12 | vallam
# Processing Record 30 of Set 12 | kimbe
# Processing Record 31 of Set 12 | san pedro buenavista
# Processing Record 32 of Set 12 | luang prabang
# Processing Record 33 of Set 12 | ayorou
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | port macquarie
# Processing Record 36 of Set 12 | najran
# Processing Record 37 of Set 12 | saint-georges
# Processing Record 38 of Set 12 | potsdam
# Processing Record 39 of Set 12 | trincomalee
# Processing Record 40 of Set 12 | nakusp
# Processing Record 41 of Set 12 | kahta
# Processing Record 42 of Set 12 | houma
# Processing Record 43 of Set 12 | ouro branco
# Processing Record 44 of Set 12 | adrar
# Processing Record 45 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 12 | calamar
# Processing Record 48 of Set 12 | sabang
# Processing Record 49 of Set 12 | macapa
# Processing Record 50 of Set 12 | kananga
# Processing Record 1 of Set 13 | toro
# Processing Record 2 of Set 13 | churapcha
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | morondava
# Processing Record 5 of Set 13 | ruteng
# Processing Record 6 of Set 13 | bosilegrad
# Processing Record 7 of Set 13 | baruun-urt
# Processing Record 8 of Set 13 | tanabe
# Processing Record 9 of Set 13 | verkhniy baskunchak
# Processing Record 10 of Set 13 | basco
# Processing Record 11 of Set 13 | leningradskiy
# Processing Record 12 of Set 13 | linxia
# Processing Record 13 of Set 13 | oyama
# Processing Record 14 of Set 13 | laplace
# Processing Record 15 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 13 | goderich
# Processing Record 17 of Set 13 | katima mulilo
# Processing Record 18 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 13 | henties bay
# Processing Record 20 of Set 13 | batagay
# Processing Record 21 of Set 13 | santo antonio da platina
# Processing Record 22 of Set 13 | xining
# Processing Record 23 of Set 13 | saint marys
# Processing Record 24 of Set 13 | aklavik
# Processing Record 25 of Set 13 | kajaani
# Processing Record 26 of Set 13 | salinas
# Processing Record 27 of Set 13 | belle glade
# Processing Record 28 of Set 13 | figeac
# Processing Record 29 of Set 13 | keelung
# Processing Record 30 of Set 13 | amapa
# Processing Record 31 of Set 13 | rialma
# Processing Record 32 of Set 13 | am timan
# Processing Record 33 of Set 13 | meru
# Processing Record 34 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 35 of Set 13 | burgeo
# Processing Record 36 of Set 13 | petropavl
# Processing Record 37 of Set 13 | lahat
# Processing Record 38 of Set 13 | mount pleasant
# Processing Record 39 of Set 13 | lucea
# Processing Record 40 of Set 13 | nueve de julio
# Processing Record 41 of Set 13 | catio
# Processing Record 42 of Set 13 | pyaozerskiy
# Processing Record 43 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 13 | dalvik
# Processing Record 45 of Set 13 | tilichiki
# Processing Record 46 of Set 13 | yar-sale
# Processing Record 47 of Set 13 | minab
# Processing Record 48 of Set 13 | tshikapa
# Processing Record 49 of Set 13 | meadow lake
# Processing Record 50 of Set 13 | tweed
# Processing Record 1 of Set 14 | togur
# Processing Record 2 of Set 14 | araouane
# Processing Record 3 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 14 | college
# Processing Record 5 of Set 14 | roros
# Processing Record 6 of Set 14 | bredy
# Processing Record 7 of Set 14 | merauke
# Processing Record 8 of Set 14 | tingi
# Processing Record 9 of Set 14 | mehamn
# Processing Record 10 of Set 14 | capinopolis
# Processing Record 11 of Set 14 | manasa
# Processing Record 12 of Set 14 | bobrovytsya
# Processing Record 13 of Set 14 | poum
# Processing Record 14 of Set 14 | tateyama
# Processing Record 15 of Set 14 | roald
# Processing Record 16 of Set 14 | torres
# Processing Record 17 of Set 14 | usoke
# Processing Record 18 of Set 14 | solenzo
# Processing Record 19 of Set 14 | ngunguru
# Processing Record 20 of Set 14 | tazovskiy
# Processing Record 21 of Set 14 | opuwo
# Processing Record 22 of Set 14 | porterville
# Processing Record 23 of Set 14 | mago
# Processing Record 24 of Set 14 | rocha
# Processing Record 25 of Set 14 | ulaanbaatar
# Processing Record 26 of Set 14 | buchanan
# Processing Record 27 of Set 14 | birecik
# Processing Record 28 of Set 14 | vila franca do campo
# Processing Record 29 of Set 14 | taft
# Processing Record 30 of Set 14 | raton
# Processing Record 31 of Set 14 | saint pete beach
# Processing Record 32 of Set 14 | virginia beach
# Processing Record 33 of Set 14 | mananjary
# Processing Record 34 of Set 14 | derzhavinsk
# Processing Record 35 of Set 14 | oriximina
# Processing Record 36 of Set 14 | bol
# Processing Record 37 of Set 14 | ternate
# Processing Record 38 of Set 14 | ukiah
# Processing Record 39 of Set 14 | middelburg
# Processing Record 40 of Set 14 | selma
# Processing Record 41 of Set 14 | guatire
# Processing Record 42 of Set 14 | mokokchung
# Processing Record 43 of Set 14 | kutum
# Processing Record 44 of Set 14 | road town
# Processing Record 45 of Set 14 | carros
# Processing Record 46 of Set 14 | vestmannaeyjar
# Processing Record 47 of Set 14 | lasa
# Processing Record 48 of Set 14 | yeniseysk
# Processing Record 49 of Set 14 | chamba
# Processing Record 50 of Set 14 | antalaha
# Processing Record 1 of Set 15 | santa cruz
# Processing Record 2 of Set 15 | tenenkou
# Processing Record 3 of Set 15 | wuhu
# Processing Record 4 of Set 15 | lubango
# Processing Record 5 of Set 15 | vallenar
# Processing Record 6 of Set 15 | gdov
# Processing Record 7 of Set 15 | sao joao da barra
# Processing Record 8 of Set 15 | valley city
# Processing Record 9 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 15 | ushiku
# Processing Record 11 of Set 15 | shelburne
# Processing Record 12 of Set 15 | laguna
# Processing Record 13 of Set 15 | zeerust
# Processing Record 14 of Set 15 | byron bay
# Processing Record 15 of Set 15 | myronivka
# Processing Record 16 of Set 15 | stephenville
# Processing Record 17 of Set 15 | teknaf
# Processing Record 18 of Set 15 | bardiyah
# Processing Record 19 of Set 15 | alyangula
# Processing Record 20 of Set 15 | anchorage
# Processing Record 21 of Set 15 | kamiiso
# Processing Record 22 of Set 15 | dera bugti
# Processing Record 23 of Set 15 | saint-ambroise
# Processing Record 24 of Set 15 | urumqi
# Processing Record 25 of Set 15 | siniscola
# Processing Record 26 of Set 15 | varva
# Processing Record 27 of Set 15 | rincon
# Processing Record 28 of Set 15 | karasjok
# Processing Record 29 of Set 15 | cedar city
# Processing Record 30 of Set 15 | asyut
# Processing Record 31 of Set 15 | havelock
# Processing Record 32 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 15 | forio
# Processing Record 34 of Set 15 | axim
# Processing Record 35 of Set 15 | yurkivka
# Processing Record 36 of Set 15 | maralal
# Processing Record 37 of Set 15 | jiangyou
# Processing Record 38 of Set 15 | buin
# Processing Record 39 of Set 15 | nipawin
# Processing Record 40 of Set 15 | cozumel
# Processing Record 41 of Set 15 | udachnyy
# Processing Record 42 of Set 15 | sari
# Processing Record 43 of Set 15 | candelaria
# Processing Record 44 of Set 15 | alta floresta
# Processing Record 45 of Set 15 | saint-francois
# Processing Record 46 of Set 15 | jinchang
# Processing Record 47 of Set 15 | kaeo
# Processing Record 48 of Set 15 | wagga wagga
# Processing Record 49 of Set 15 | locri
# Processing Record 50 of Set 15 | vilcun
# Processing Record 1 of Set 16 | karakendzha
# City not found. Skipping...
# Processing Record 2 of Set 16 | bairiki
# Processing Record 3 of Set 16 | muisne
# Processing Record 4 of Set 16 | maragogi
# Processing Record 5 of Set 16 | nhulunbuy
# Processing Record 6 of Set 16 | hojai
# Processing Record 7 of Set 16 | evensk
# Processing Record 8 of Set 16 | dibrugarh
# Processing Record 9 of Set 16 | padang
# Processing Record 10 of Set 16 | deputatskiy
# Processing Record 11 of Set 16 | sandwick
# Processing Record 12 of Set 16 | north bend
# Processing Record 13 of Set 16 | porto novo
# Processing Record 14 of Set 16 | beberibe
# Processing Record 15 of Set 16 | vertientes
# Processing Record 16 of Set 16 | birin
# Processing Record 17 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 16 | omboue
# Processing Record 19 of Set 16 | san
# Processing Record 20 of Set 16 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 16 | paita
# Processing Record 22 of Set 16 | jimenez
# Processing Record 23 of Set 16 | tiznit
# Processing Record 24 of Set 16 | aranos
# Processing Record 25 of Set 16 | yulara
# Processing Record 26 of Set 16 | kushima
# Processing Record 27 of Set 16 | esna
# Processing Record 28 of Set 16 | orgun
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list then add to a DF
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Sao Felix Do Xingu      BR  -6.6447  -51.9950     70.81        99
# 1               Rikitea      PF -23.1203 -134.9692     77.72        76
# 2           Provideniya      RU  64.3833 -173.3000     17.71        53
# 3             Carnarvon      AU -24.8667  113.6333     86.11        49
# 4               Sharjah      AE  25.3573   55.4033     69.78        82
# ..                  ...     ...      ...       ...       ...       ...
# 716              Tiznit      MA  29.5833   -9.5000     56.95        31
# 717              Aranos      NA -24.1333   19.1167     70.56        22
# 718              Yulara      AU -25.2406  130.9889     94.05        34
# 719             Kushima      JP  31.4583  131.2333     53.74        37
# 720                Esna      EG  25.2934   32.5540     51.82        67
#
#      Cloudiness  Wind Speed Current Description
# 0           100        1.63     overcast clouds
# 1            39        6.89    scattered clouds
# 2             2       35.79           clear sky
# 3             8       21.54           clear sky
# 4             0        5.75           clear sky
# ..          ...         ...                 ...
# 716          17       20.76          few clouds
# 717          12        8.61          few clouds
# 718          89       17.65     overcast clouds
# 719           3        4.83           clear sky
# 720           0        8.39           clear sky
#
# [721 rows x 9 columns]

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Sao Felix Do Xingu      BR  -6.6447  -51.9950     70.81        99
# 1             Rikitea      PF -23.1203 -134.9692     77.72        76
# 2         Provideniya      RU  64.3833 -173.3000     17.71        53
# 3           Carnarvon      AU -24.8667  113.6333     86.11        49
# 4             Sharjah      AE  25.3573   55.4033     69.78        82
# 5              Vostok      RU  46.4856  135.8833     11.37        89
# 6          Sungairaya      ID   0.7000  108.9000     83.52        73
# 7                Hofn      IS  64.2539  -15.2082     28.56        54
# 8         Sargatskoye      RU  55.6101   73.4972     10.53        80
# 9           Busselton      AU -33.6500  115.3333     75.92        42
#
#    Cloudiness  Wind Speed Current Description
# 0         100        1.63     overcast clouds
# 1          39        6.89    scattered clouds
# 2           2       35.79           clear sky
# 3           8       21.54           clear sky
# 4           0        5.75           clear sky
# 5         100        3.44     overcast clouds
# 6          95       10.92          light rain
# 7         100       29.24     overcast clouds
# 8          11       10.49          few clouds
# 9          55       16.44       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_weather_file = "Weatherpy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
